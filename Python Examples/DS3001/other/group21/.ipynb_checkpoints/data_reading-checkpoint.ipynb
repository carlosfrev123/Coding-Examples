# %% [markdown]
# Code for analyzing the flu vaccine by age, sex, and marital

# %%
import numpy as np # Import the numpy package into your workspace
import pandas as pd  # Import the pandas package into your workspace
df = pd.read_csv("./gss.csv", low_memory=False)
print(df.shape)
df.head()
print(df.columns)
filtered_df = df[(df['year']==2018)| (df['year']==2021) | (df['year']==2022)]
# Out:
# (72390, 6645)
# Index(['Unnamed: 0', 'year', 'id', 'wrkstat', 'hrs1', 'hrs2', 'evwork', 'occ',
#        'prestige', 'wrkslf',
#        ...
#        'instype02', 'instype03', 'instype04', 'totalincentive', 'wtssps_nea',
#        'wtssnrps_nea', 'wtssps_next', 'wtssnrps_next', 'wtsscomp',
#        'wtsscompnr'],
#       dtype='object', length=6645)

# %%
selected_columns = ['age', 'sex', 'marital', 'fluvax']
final_data_frame = filtered_df[selected_columns]


final_data_frame = final_data_frame.dropna(subset=['fluvax', 'age'])

nan_counts = final_data_frame.isna().sum()
print(nan_counts)

print(final_data_frame.shape)
print(final_data_frame.head())
# Out:
# age        0
# sex        0
# marital    0
# fluvax     0
# dtype: int64
# (1198, 4)
#         age     sex        marital fluvax
# 68846  72.0  female       divorced    yes
# 68849  23.0  female  never married     no
# 68850  62.0    male  never married     no
# 68856  57.0  female        widowed     no
# 68863  80.0  female        married    yes

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.figure(figsize=(10, 6))
# age_range = range(0, 130, 10)
plt.hist(final_data_frame[final_data_frame['fluvax'] == 'yes']['age'], bins=100, alpha=0.5, label='Flu Vaccinated', color='blue')
plt.hist(final_data_frame[final_data_frame['fluvax'] == 'no']['age'], bins=100, alpha=0.5, label='Not Vaccinated', color='red')

# Set the y-axis limits to show frequencies within the range of 1 to 500
# plt.ylim(1, 500)

# Add labels and legend
plt.xlabel('Age')
plt.ylabel('Frequency %')
plt.title('Flu Vaccination vs Age Histogram')
plt.legend()

# Show the histogram
plt.show()

# %%
import seaborn as sns

# Assuming you have your 'final_data_frame' with 'sex' and 'fluvax' columns

# Create a count plot
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', hue='fluvax', data=final_data_frame, palette='Set1')

# Set labels and title
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Flu Vaccination by Gender')

# Show the legend for the 'fluvax' values
plt.legend(title='Flu Vaccination', labels=['Not Vaccinated', 'Vaccinated'])

# Show the graph
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='marital', hue='fluvax', data=final_data_frame, palette='Set1')

# Set labels and title
plt.xlabel('Marital')
plt.ylabel('Count')
plt.title('Flu Vaccination by Marital Status')

# Show the legend for the 'fluvax' values
plt.legend(title='Flu Vaccination', labels=['Not Vaccinated', 'Vaccinated'])

# Show the graph
plt.show()

# %%
year1_df = df[(df['year']==2022)]

selected_columns = ['age', 'sex', 'marital', 'fluvax']
final_data_frame_year1 = year1_df[selected_columns]


#unique_columns = df['year'].unique()
#print(unique_columns)

final_data_frame_year1 = final_data_frame_year1.dropna(subset=['fluvax', 'age'])

plt.figure(figsize=(10, 6))
# age_range = range(0, 130, 10)
plt.hist(final_data_frame_year1[final_data_frame_year1['fluvax'] == 'yes']['age'], bins=100, alpha=0.5, label='Flu Vaccinated', color='blue')
plt.hist(final_data_frame_year1[final_data_frame_year1['fluvax'] == 'no']['age'], bins=100, alpha=0.5, label='Not Vaccinated', color='red')

# Set the y-axis limits to show frequencies within the range of 1 to 500
# plt.ylim(1, 500)

# Add labels and legend
plt.xlabel('Age')
plt.ylabel('Frequency %')
plt.title('Flu Vaccination vs Age Histogram (2022)')
plt.legend()

print(final_data_frame_year1.shape)

# Show the histogram
plt.show()
# Out:
# (1198, 4)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', hue='fluvax', data=final_data_frame_year1, palette='Set1')

# Set labels and title
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Flu Vaccination by Gender 2022')

# Show the legend for the 'fluvax' values
plt.legend(title='Flu Vaccination', labels=['Not Vaccinated', 'Vaccinated'])

# Show the graph
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='marital', hue='fluvax', data=final_data_frame_year1, palette='Set1')

# Set labels and title
plt.xlabel('Marital')
plt.ylabel('Count')
plt.title('Flu Vaccination by Marital Status 2021')

# Show the legend for the 'fluvax' values
plt.legend(title='Flu Vaccination', labels=['Not Vaccinated', 'Vaccinated'])

# Show the graph
plt.show()

# %%
from scipy.stats import chi2_contingency

# For Gender and Fluvax
contingency_gender_fluvax = pd.crosstab(final_data_frame['sex'], final_data_frame['fluvax'])
chi2_gender, p_gender, _, _ = chi2_contingency(contingency_gender_fluvax)

# For Marital Status and Fluvax
contingency_marital_fluvax = pd.crosstab(final_data_frame['marital'], final_data_frame['fluvax'])
chi2_marital, p_marital, _, _ = chi2_contingency(contingency_marital_fluvax)

# Printing the p-values
print(f"P-value for correlation between Gender and Fluvax: {p_gender:.4f}")
print(f"P-value for correlation between Marital Status and Fluvax: {p_marital:.9f}")

# Check if the correlations are statistically significant (typically at p < 0.05)
if p_gender < 0.05:
    print("There is a statistically significant correlation between Gender and Fluvax.")
else:
    print("There isn't a statistically significant correlation between Gender and Fluvax.")

if p_marital < 0.05:
    print("There is a statistically significant correlation between Marital Status and Fluvax.")
else:
    print("There isn't a statistically significant correlation between Marital Status and Fluvax.")


print("-------------------------------------------------------------")
print("Statistical tests are conducted at a 0.05 significance level.")
# Out:
# P-value for correlation between Gender and Fluvax: 0.9264
# P-value for correlation between Marital Status and Fluvax: 0.000000004
# There isn't a statistically significant correlation between Gender and Fluvax.
# There is a statistically significant correlation between Marital Status and Fluvax.
# -------------------------------------------------------------
# Statistical tests are conducted at a 0.05 significance level.
